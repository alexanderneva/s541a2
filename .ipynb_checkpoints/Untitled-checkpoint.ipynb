# %% [markdown]
# # Question 1: Quadratic Discriminant Analysis
#
# - logistic function f(x):
# $$f(x) = \frac{e^x}{1+e^x}$$
# - selecting a class $K$ for the logistic baseline
# $$P(Y=K|X=x)=\frac{1}{1+\sum_{l=1}^{K-1}e^{\beta_{l0}+\beta_{l1}x_{0}+\dots+\beta_{lp}x_{lp}}}$$
# which is the probability that $Y$ belongs to the class $K$ we have selected as baseline

# %% [markdown]
# # Question 4
#
# ## Part a)

# %%
import pandas as pd
import numpy as np
from ISLP import load_data
auto = load_data('Auto')
auto.columns
